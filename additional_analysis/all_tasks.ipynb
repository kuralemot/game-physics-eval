# %%
import pandas as pd
import os
from pathlib import Path

# %%
base_dir = Path('..') / 'evaluation'  # Adjust path if needed
tasks = ['task_1', 'task_2', 'task_3']
modality_list = ['xml', 'json', 'image']

accuracy_records = []
invalid_records = []

# %%
for task in tasks:
    task_path = base_dir / task
    for pe_type in task_path.iterdir():
        if not pe_type.is_dir():
            continue
        for model in pe_type.iterdir():
            if not model.is_dir():
                continue
            for file in model.glob("*.csv"):
                modality = file.stem.lower()  # e.g., xml, json, image
                df = pd.read_csv(file)
                
                # Accuracy
                acc = round(df['score'].mean(), 2)
                accuracy_records.append({
                    'model': model.name,
                    'pe_type': pe_type.name,
                    'task': task,
                    'modality': modality,
                    'accuracy': acc
                })

                # Count invalids
                invalid_count = int((df['answer'].astype(str).str.lower() == "invalid").sum())
                invalid_records.append({
                    'model': model.name,
                    'pe_type': pe_type.name,
                    'task': task,
                    'modality': modality,
                    'invalid_count': invalid_count
                })

# %%
# Convert to DataFrames
acc_df = pd.DataFrame(accuracy_records)
inv_df = pd.DataFrame(invalid_records)

# Pivot for final tables
acc_pivot = acc_df.pivot_table(index=['model', 'pe_type'], 
                                columns=['task', 'modality'], 
                                values='accuracy')

inv_pivot = inv_df.pivot_table(index=['model', 'pe_type'], 
                                columns=['task', 'modality'], 
                                values='invalid_count', fill_value=0)

# Optional: Flatten MultiIndex columns
acc_pivot.columns = [f'{t.upper()} {m.upper()}' for t, m in acc_pivot.columns]
inv_pivot.columns = [f'{t.upper()} {m.upper()}' for t, m in inv_pivot.columns]

# Format invalid table values as integers
inv_pivot = inv_pivot.astype(int)

# Display
print("=== Accuracy Table ===")
display(acc_pivot.reset_index())

print("\n=== Invalid Answer Count Table ===")
display(inv_pivot.reset_index())
# Out:
# === Accuracy Table ===
#             model        pe_type  TASK_1 IMAGE  TASK_1 JSON  TASK_1 XML  \
# 0       gemma3-4b      null-shot          0.54         0.46        0.51
# 1       gemma3-4b  null-shot-cot          0.53         0.57        0.55
# 2       gemma3-4b      zero-shot          0.55         0.56        0.57
# 3       gemma3-4b  zero-shot-cot          0.51         0.51        0.55
# 4    gpt_4-1-mini      null-shot          0.55         0.52        0.53
# 5    gpt_4-1-mini  null-shot-cot          0.55         0.56        0.54
# 6    gpt_4-1-mini      zero-shot          0.58         0.51        0.50
# 7    gpt_4-1-mini  zero-shot-cot          0.59         0.55        0.55
# 8          gpt_4o      null-shot          0.65         0.50        0.50
# 9          gpt_4o  null-shot-cot          0.65         0.48        0.52
# 10         gpt_4o      zero-shot          0.64         0.49        0.48
# 11         gpt_4o  zero-shot-cot          0.62         0.49        0.51
# 12       llava-7b      null-shot          0.50         0.54        0.45
# 13       llava-7b  null-shot-cot          0.50         0.54        0.56
# 14       llava-7b      zero-shot          0.50         0.51        0.51
# 15       llava-7b  zero-shot-cot          0.50         0.48        0.51
# 16  qwen2.5-vl-3b      null-shot          0.50         0.49        0.50
# 17  qwen2.5-vl-3b  null-shot-cot          0.49         0.48        0.50
# 18  qwen2.5-vl-3b      zero-shot          0.49         0.52        0.51
# 19  qwen2.5-vl-3b  zero-shot-cot          0.48         0.51        0.52
# 20  qwen2.5-vl-7b      null-shot          0.48         0.50        0.45
# 21  qwen2.5-vl-7b  null-shot-cot          0.46         0.50        0.54
# 22  qwen2.5-vl-7b      zero-shot          0.51         0.46        0.53
# 23  qwen2.5-vl-7b  zero-shot-cot          0.54         0.51        0.49
#
#     TASK_2 IMAGE  TASK_2 JSON  TASK_2 XML  TASK_3 IMAGE  TASK_3 JSON  \
# 0           0.40         0.30        0.31          0.20         0.18
# 1           0.38         0.31        0.32          0.16         0.17
# 2           0.40         0.35        0.36          0.18         0.14
# 3           0.39         0.30        0.40          0.21         0.19
# 4           0.60         0.46        0.42          0.44         0.70
# 5           0.64         0.47        0.43          0.42         0.71
# 6           0.59         0.41        0.45          0.50         0.73
# 7           0.60         0.51        0.47          0.47         0.68
# 8           0.71         0.50        0.47          0.79         0.62
# 9           0.71         0.49        0.49          0.76         0.64
# 10          0.72         0.52        0.47          0.76         0.66
# 11          0.70         0.49        0.48          0.78         0.63
# 12          0.19         0.32        0.35          0.22         0.20
# 13          0.20         0.33        0.32          0.20         0.21
# 14          0.20         0.37        0.34          0.16         0.19
# 15          0.23         0.32        0.35          0.20         0.20
# 16          0.30         0.35        0.38          0.21         0.22
# 17          0.35         0.36        0.38          0.22         0.21
# 18          0.34         0.38        0.38          0.22         0.22
# 19          0.36         0.38        0.34          0.29         0.21
# 20          0.39         0.34        0.37          0.25         0.18
# 21          0.40         0.35        0.37          0.23         0.18
# 22          0.41         0.38        0.36          0.24         0.18
# 23          0.40         0.37        0.38          0.21         0.17
#
#     TASK_3 XML
# 0         0.32
# 1         0.33
# 2         0.31
# 3         0.32
# 4         0.76
# 5         0.78
# 6         0.83
# 7         0.81
# 8         0.64
# 9         0.65
# 10        0.66
# 11        0.61
# 12        0.32
# 13        0.30
# 14        0.39
# 15        0.40
# 16        0.28
# 17        0.32
# 18        0.30
# 19        0.30
# 20        0.50
# 21        0.47
# 22        0.52
# 23        0.53
# === Invalid Answer Count Table ===
#             model        pe_type  TASK_1 IMAGE  TASK_1 JSON  TASK_1 XML  \
# 0       gemma3-4b      null-shot             1            0           3
# 1       gemma3-4b  null-shot-cot             0            0           3
# 2       gemma3-4b      zero-shot             0            1           2
# 3       gemma3-4b  zero-shot-cot             0            1           9
# 4    gpt_4-1-mini      null-shot             0            0           0
# 5    gpt_4-1-mini  null-shot-cot             0            0           0
# 6    gpt_4-1-mini      zero-shot             0            0           0
# 7    gpt_4-1-mini  zero-shot-cot             0            0           0
# 8          gpt_4o      null-shot             0            0           0
# 9          gpt_4o  null-shot-cot             0            0           0
# 10         gpt_4o      zero-shot             0            0           0
# 11         gpt_4o  zero-shot-cot             0            0           0
# 12       llava-7b      null-shot             0            0           1
# 13       llava-7b  null-shot-cot             0            0           0
# 14       llava-7b      zero-shot             0            0           0
# 15       llava-7b  zero-shot-cot             0            0           0
# 16  qwen2.5-vl-3b      null-shot             0            0           4
# 17  qwen2.5-vl-3b  null-shot-cot             1            1           0
# 18  qwen2.5-vl-3b      zero-shot             0            1           8
# 19  qwen2.5-vl-3b  zero-shot-cot             3            0           0
# 20  qwen2.5-vl-7b      null-shot             0            0          18
# 21  qwen2.5-vl-7b  null-shot-cot             0            0           0
# 22  qwen2.5-vl-7b      zero-shot             0            1           0
# 23  qwen2.5-vl-7b  zero-shot-cot             0            0           3
#
#     TASK_2 IMAGE  TASK_2 JSON  TASK_2 XML  TASK_3 IMAGE  TASK_3 JSON  \
# 0              7           42           3            20           92
# 1             14           47           5            42           92
# 2              1           43           4            27           99
# 3              9           43           5            74           91
# 4              0            0           0             0            0
# 5              0            0           0             0            0
# 6              0            0           0             0            0
# 7              0            0           0             0            0
# 8              0            0           0             0            0
# 9              0            0           0             0            0
# 10             0            0           0             0            0
# 11             0            0           0             0            0
# 12             2           31           0            24           36
# 13             0           31           3            17           63
# 14             1           32           0            41           98
# 15            13           32           2            34           68
# 16            37           28          11            54           57
# 17             0           25           9             4           60
# 18            19           25           9            33           21
# 19            11           23           7             1           60
# 20             1           36           2            47          122
# 21             0           37           0            35          122
# 22             2           37           3            30          112
# 23             6           35           2            27          123
#
#     TASK_3 XML
# 0            3
# 1            0
# 2            1
# 3            1
# 4            0
# 5            0
# 6            0
# 7            0
# 8            0
# 9            0
# 10           0
# 11           0
# 12          32
# 13          43
# 14          31
# 15          32
# 16          33
# 17          35
# 18          34
# 19          32
# 20           1
# 21           2
# 22           0
# 23           2

# %%
inv_summary = inv_df.groupby(['model', 'task', 'modality'])['invalid_count'].sum().reset_index()
inv_summary_pivot = inv_summary.pivot(index='model', columns=['task', 'modality'], values='invalid_count').fillna(0).astype(int)
inv_summary_pivot.columns = [f"{task.upper()} {modality.upper()}" for task, modality in inv_summary_pivot.columns]
inv_summary_pivot = inv_summary_pivot.reset_index()
print("\n=== Invalid Answer Count Table (No PE Type) ===")
display(inv_summary_pivot)
# Out:
# === Invalid Answer Count Table (No PE Type) ===
#            model  TASK_1 IMAGE  TASK_1 JSON  TASK_1 XML  TASK_2 IMAGE  \
# 0      gemma3-4b             1            2          17            31
# 1   gpt_4-1-mini             0            0           0             0
# 2         gpt_4o             0            0           0             0
# 3       llava-7b             0            0           1            16
# 4  qwen2.5-vl-3b             4            2          12            67
# 5  qwen2.5-vl-7b             0            1          21             9
#
#    TASK_2 JSON  TASK_2 XML  TASK_3 IMAGE  TASK_3 JSON  TASK_3 XML
# 0          175          17           163          374           5
# 1            0           0             0            0           0
# 2            0           0             0            0           0
# 3          126           5           116          265         138
# 4          101          36            92          198         134
# 5          145           7           139          479           5

# %%
# # Save both tables into one Excel file with separate sheets
# output_path = Path('all_task_results.xlsx')  # Save in current directory

# with pd.ExcelWriter(output_path, engine='xlsxwriter') as writer:
#     acc_pivot.reset_index().to_excel(writer, index=False, sheet_name='Accuracy')
#     inv_pivot.reset_index().to_excel(writer, index=False, sheet_name='Invalid Counts')
#     inv_summary_pivot.to_excel(writer, index=False, sheet_name='Invalid Counts (No PE Type)')
# print(f"Saved results to {output_path}")
# Out:
# Saved results to all_task_results.xlsx

# %%
task1_acc_df = acc_df[acc_df['task'] == 'task_1']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 task1_acc_df = acc_df[acc_df['task'] == 'task_1']
#
# NameError: name 'acc_df' is not defined
