# %%
import json

with open('../data/task_3/summary.json', 'r') as f:
    summary_data = json.load(f)

# Create a mapping from ID to metadata
summary_mapping = {item['id']: {
    'task_mode': item['task_mode'],
    'correct_answer': item['correct_answer']
} for item in summary_data['gt']}

# %%
import pandas as pd
from pathlib import Path

evaluation_path = Path('../evaluation/task_3/')
records = []

for pe_type_dir in evaluation_path.iterdir():
    if pe_type_dir.is_dir():
        for model_dir in pe_type_dir.iterdir():
            if model_dir.is_dir():
                for file_path in model_dir.glob('*.csv'):
                    modality = file_path.stem.lower()
                    df = pd.read_csv(file_path)

                    for _, row in df.iterrows():
                        file_name = Path(row['file']).name
                        question_id = file_name.split('_')[0]
                        metadata = summary_mapping.get(question_id)

                        if metadata:
                            is_correct = row['answer'].strip().upper() == metadata['correct_answer'].strip().upper()
                            records.append({
                                'model': model_dir.name,
                                'pe_type': pe_type_dir.name,
                                'modality': modality,
                                'task_mode': metadata['task_mode'],
                                'is_correct': is_correct,
                                'selected_option': row['answer'].strip().upper()
                            })

# %%
analysis_df = pd.DataFrame(records)

# Performance by hidden task
performance_task = analysis_df.groupby(['model', 'pe_type', 'modality', 'task_mode'])['is_correct'].agg(['sum', 'count']).reset_index()
performance_task.rename(columns={'sum': 'correct', 'count': 'total'}, inplace=True)

# Bias towards specific options
bias_options = analysis_df.groupby(['model', 'pe_type', 'modality', 'selected_option']).size().reset_index(name='selected_count')
total_questions = analysis_df.groupby(['model', 'pe_type', 'modality']).size().reset_index(name='total_questions')
bias_options = bias_options.merge(total_questions, on=['model', 'pe_type', 'modality'])
bias_options['selection_rate'] = bias_options['selected_count'] / bias_options['total_questions']

# Display
print("=== Performance by task ===")
display(performance_task)

print("\n=== Bias towards specific options ===")
display(bias_options)
# Out:
# === Performance by task ===
#              model        pe_type modality              task_mode  correct  \
# 0        gemma3-4b      null-shot    image  prediction_diff_block       21
# 1        gemma3-4b      null-shot    image     prediction_diff_id       24
# 2        gemma3-4b      null-shot    image  prediction_diff_level       15
# 3        gemma3-4b      null-shot     json  prediction_diff_block       24
# 4        gemma3-4b      null-shot     json     prediction_diff_id       18
# ..             ...            ...      ...                    ...      ...
# 211  qwen2.5-vl-7b  zero-shot-cot     json     prediction_diff_id       20
# 212  qwen2.5-vl-7b  zero-shot-cot     json  prediction_diff_level       18
# 213  qwen2.5-vl-7b  zero-shot-cot      xml  prediction_diff_block       54
# 214  qwen2.5-vl-7b  zero-shot-cot      xml     prediction_diff_id       58
# 215  qwen2.5-vl-7b  zero-shot-cot      xml  prediction_diff_level       47
#
#      total
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
# ..     ...
# 211    100
# 212    100
# 213    100
# 214    100
# 215    100
#
# [216 rows x 6 columns]
# === Bias towards specific options ===
#              model        pe_type modality selected_option  selected_count  \
# 0        gemma3-4b      null-shot    image               A              30
# 1        gemma3-4b      null-shot    image               B              52
# 2        gemma3-4b      null-shot    image               C              83
# 3        gemma3-4b      null-shot    image               D             115
# 4        gemma3-4b      null-shot    image         INVALID              20
# ..             ...            ...      ...             ...             ...
# 328  qwen2.5-vl-7b  zero-shot-cot      xml               A             116
# 329  qwen2.5-vl-7b  zero-shot-cot      xml               B              83
# 330  qwen2.5-vl-7b  zero-shot-cot      xml               C              36
# 331  qwen2.5-vl-7b  zero-shot-cot      xml               D              63
# 332  qwen2.5-vl-7b  zero-shot-cot      xml         INVALID               2
#
#      total_questions  selection_rate
# 0                300        0.100000
# 1                300        0.173333
# 2                300        0.276667
# 3                300        0.383333
# 4                300        0.066667
# ..               ...             ...
# 328              300        0.386667
# 329              300        0.276667
# 330              300        0.120000
# 331              300        0.210000
# 332              300        0.006667
#
# [333 rows x 7 columns]

# %%
with pd.ExcelWriter('task_3_analysis.xlsx') as writer:
    performance_task.to_excel(writer, sheet_name='Performance_Hidden_Task', index=False)
    bias_options.to_excel(writer, sheet_name='Bias_Options', index=False)

# %%
performance_task = (
    analysis_df
    .groupby(['model', 'pe_type', 'modality', 'task_mode'])['is_correct']
    .agg(['sum', 'count'])
    .reset_index()
    .rename(columns={'sum': 'correct', 'count': 'total'})
)

# %%
#performance_pivot.to_excel('task_3_performance_summary.xlsx', index=False)
performance_pivot.to_excel('task_3_performance_summary.xlsx', index=False)

# %%
# Create pivot table for performance
performance_pivot = (
    performance_task
    .pivot(index=['model', 'pe_type', 'modality'], columns='task_mode', values=['correct', 'total'])
)
performance_pivot.columns = [
    f"{task_mode}_{metric}"
    for metric, task_mode in performance_pivot.columns
]
performance_pivot = performance_pivot.reset_index()
desired_order = [
    'model', 'pe_type', 'modality',
    'prediction_diff_block_correct', 'prediction_diff_block_total',
    'prediction_diff_level_correct', 'prediction_diff_level_total',
    'prediction_diff_id_correct', 'prediction_diff_id_total'
]
performance_pivot = performance_pivot[desired_order]

# Create the additional tables
# GPT-4o Option Performance
gpt4o_option_performance = (
    analysis_df[analysis_df['model'] == 'gpt_4o']
    .groupby(['pe_type', 'modality'])['is_correct']
    .mean()
    .reset_index()
    .rename(columns={'is_correct': 'accuracy'})
)

# GPT-4o Subtask Performance
gpt4o_subtask = (
    analysis_df[analysis_df['model'] == 'gpt_4o']
    .groupby(['modality', 'task_mode'])['is_correct']
    .mean()
    .reset_index()
    .rename(columns={'is_correct': 'accuracy'})
)

# GPT-4-1-mini Option Performance
gpt4_1_mini_option_performance = (
    analysis_df[analysis_df['model'] == 'gpt_4-1-mini']
    .groupby(['pe_type', 'modality'])['is_correct']
    .mean()
    .reset_index()
    .rename(columns={'is_correct': 'accuracy'})
)

# GPT-4-1-mini Subtask Performance
gpt4_1_mini_subtask = (
    analysis_df[analysis_df['model'] == 'gpt_4-1-mini']
    .groupby(['modality', 'task_mode'])['is_correct']
    .mean()
    .reset_index()
    .rename(columns={'is_correct': 'accuracy'})
)

# # Display all tables
# print("=== Performance by task ===")
# display(performance_pivot)

# print("\n=== Bias towards specific options ===")
# display(bias_options)

print("\n=== GPT-4o Option Performance ===")
display(gpt4o_option_performance)

print("\n=== GPT-4o Subtask Performance ===")
display(gpt4o_subtask)

print("\n=== GPT-4-1-mini Option Performance ===")
display(gpt4_1_mini_option_performance)

print("\n=== GPT-4-1-mini Subtask Performance ===")
display(gpt4_1_mini_subtask)

# Save all tables to Excel
with pd.ExcelWriter('task_3_analysis.xlsx') as writer:
    performance_pivot.to_excel(writer, sheet_name='Performance_Summary', index=False)
    bias_options.to_excel(writer, sheet_name='Bias_Options', index=False)
    gpt4o_option_performance.to_excel(writer, sheet_name='GPT4o_Option_Performance', index=False)
    gpt4o_subtask.to_excel(writer, sheet_name='GPT4o_Subtask', index=False)
    gpt4_1_mini_option_performance.to_excel(writer, sheet_name='GPT4_1_mini_Option_Performance', index=False)
    gpt4_1_mini_subtask.to_excel(writer, sheet_name='GPT4_1_mini_Subtask', index=False)
# Out:
# === Focus Models Performance by task ===
#            model        pe_type modality              task_mode  correct  \
# 0   gpt_4-1-mini      null-shot    image  prediction_diff_block       46
# 1   gpt_4-1-mini      null-shot    image     prediction_diff_id       50
# 2   gpt_4-1-mini      null-shot    image  prediction_diff_level       35
# 3   gpt_4-1-mini      null-shot     json  prediction_diff_block       74
# 4   gpt_4-1-mini      null-shot     json     prediction_diff_id       71
# ..           ...            ...      ...                    ...      ...
# 67        gpt_4o  zero-shot-cot     json     prediction_diff_id       57
# 68        gpt_4o  zero-shot-cot     json  prediction_diff_level       58
# 69        gpt_4o  zero-shot-cot      xml  prediction_diff_block       72
# 70        gpt_4o  zero-shot-cot      xml     prediction_diff_id       45
# 71        gpt_4o  zero-shot-cot      xml  prediction_diff_level       65
#
#     total
# 0     100
# 1     100
# 2     100
# 3     100
# 4     100
# ..    ...
# 67    100
# 68    100
# 69    100
# 70    100
# 71    100
#
# [72 rows x 6 columns]
# === Focus Models Bias towards specific options ===
#            model        pe_type modality selected_option  selected_count  \
# 0   gpt_4-1-mini      null-shot    image               A             112
# 1   gpt_4-1-mini      null-shot    image               B              66
# 2   gpt_4-1-mini      null-shot    image               C              61
# 3   gpt_4-1-mini      null-shot    image               D              61
# 4   gpt_4-1-mini      null-shot     json               A              92
# ..           ...            ...      ...             ...             ...
# 91        gpt_4o  zero-shot-cot     json               D              32
# 92        gpt_4o  zero-shot-cot      xml               A             162
# 93        gpt_4o  zero-shot-cot      xml               B              61
# 94        gpt_4o  zero-shot-cot      xml               C              53
# 95        gpt_4o  zero-shot-cot      xml               D              24
#
#     total_questions  selection_rate
# 0               300        0.373333
# 1               300        0.220000
# 2               300        0.203333
# 3               300        0.203333
# 4               300        0.306667
# ..              ...             ...
# 91              300        0.106667
# 92              300        0.540000
# 93              300        0.203333
# 94              300        0.176667
# 95              300        0.080000
#
# [96 rows x 7 columns]
# === Focus Models Performance Pivot ===
#            model        pe_type modality  prediction_diff_block_correct  \
# 0   gpt_4-1-mini      null-shot    image                             46
# 1   gpt_4-1-mini      null-shot     json                             74
# 2   gpt_4-1-mini      null-shot      xml                             75
# 3   gpt_4-1-mini  null-shot-cot    image                             42
# 4   gpt_4-1-mini  null-shot-cot     json                             75
# 5   gpt_4-1-mini  null-shot-cot      xml                             80
# 6   gpt_4-1-mini      zero-shot    image                             51
# 7   gpt_4-1-mini      zero-shot     json                             72
# 8   gpt_4-1-mini      zero-shot      xml                             82
# 9   gpt_4-1-mini  zero-shot-cot    image                             48
# 10  gpt_4-1-mini  zero-shot-cot     json                             69
# 11  gpt_4-1-mini  zero-shot-cot      xml                             84
# 12        gpt_4o      null-shot    image                             85
# 13        gpt_4o      null-shot     json                             74
# 14        gpt_4o      null-shot      xml                             77
# 15        gpt_4o  null-shot-cot    image                             82
# 16        gpt_4o  null-shot-cot     json                             77
# 17        gpt_4o  null-shot-cot      xml                             79
# 18        gpt_4o      zero-shot    image                             88
# 19        gpt_4o      zero-shot     json                             77
# 20        gpt_4o      zero-shot      xml                             80
# 21        gpt_4o  zero-shot-cot    image                             88
# 22        gpt_4o  zero-shot-cot     json                             75
# 23        gpt_4o  zero-shot-cot      xml                             72
#
#     prediction_diff_block_total  prediction_diff_level_correct  \
# 0                           100                             35
# 1                           100                             66
# 2                           100                             73
# 3                           100                             33
# 4                           100                             63
# 5                           100                             71
# 6                           100                             42
# 7                           100                             67
# 8                           100                             78
# 9                           100                             40
# 10                          100                             55
# 11                          100                             77
# 12                          100                             75
# 13                          100                             64
# 14                          100                             66
# 15                          100                             69
# 16                          100                             66
# 17                          100                             66
# 18                          100                             62
# 19                          100                             66
# 20                          100                             65
# 21                          100                             65
# 22                          100                             58
# 23                          100                             65
#
#     prediction_diff_level_total  prediction_diff_id_correct  \
# 0                           100                          50
# 1                           100                          71
# 2                           100                          81
# 3                           100                          51
# 4                           100                          75
# 5                           100                          83
# 6                           100                          57
# 7                           100                          81
# 8                           100                          89
# 9                           100                          53
# 10                          100                          80
# 11                          100                          83
# 12                          100                          77
# 13                          100                          48
# 14                          100                          50
# 15                          100                          76
# 16                          100                          48
# 17                          100                          49
# 18                          100                          77
# 19                          100                          55
# 20                          100                          52
# 21                          100                          80
# 22                          100                          57
# 23                          100                          45
#
#     prediction_diff_id_total
# 0                        100
# 1                        100
# 2                        100
# 3                        100
# 4                        100
# 5                        100
# 6                        100
# 7                        100
# 8                        100
# 9                        100
# 10                       100
# 11                       100
# 12                       100
# 13                       100
# 14                       100
# 15                       100
# 16                       100
# 17                       100
# 18                       100
# 19                       100
# 20                       100
# 21                       100
# 22                       100
# 23                       100
